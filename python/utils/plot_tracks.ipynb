# %%
from root_numpy import root2array
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


filename = "~/Downloads/sync_gpvm/LaserReco-7205-0790.root"
tree = "Events"
branch = "recob::Tracks_pandoraCosmic__Laser.obj.fXYZ.f"

# %%
x = root2array(filename, treename=tree, branches=branch + "X", start=0,stop=1,)
y = root2array(filename, treename=tree, branches=branch + "Y", start=0,stop=1,)
z = root2array(filename, treename=tree, branches=branch + "Z", start=0,stop=1,)

# %%
x[0]
# Out:
# array([ 218.4752655 ,  218.46939087,  218.43965149, ...,  115.72761536,
#         115.81684113,  116.10250092])

# %%
plt.scatter(z[0], x[0])
